# %% [markdown]
# <a href="https://colab.research.google.com/github/LAGRA01251467/Ciencia-de-Datos-A01251467/blob/main/Actividad5Preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: LUIS ALBERTO GUTIÉRREZ RIVERA
# *   MATRÍCULA: A01251467

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
print("Información del DataFrame:")
print(response_df.info())
n_vars = response_df.select_dtypes(include=['number']).columns
t_vars = response_df.select_dtypes(include=['object']).columns
print(f"\nNúmero de variables numéricas: {len(n_vars)}")
print(f"Número de variables de texto: {len(t_vars)}")
print("\nEstadísticas descriptivas para variables numéricas:")
print(response_df.describe())
print("\nResumen de variables numéricas:")
print(response_df.describe())
print("\nResumen de variables categóricas:")
print(response_df.describe(include=['object']))
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB
# None
#
# Número de variables numéricas: 139
# Número de variables de texto: 11
#
# Estadísticas descriptivas para variables numéricas:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# ...

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.
# El uso del histograma es mucho mejor ya que este puede desplegar la información de la frecuencia de los valores en los intervalos necesarios.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(response_df['Weight'], bins=20, kde=True)
plt.title('Distribución de Peso')
plt.xlabel('Weight')
plt.ylabel('Frequencia')
plt.show()

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.
#
# La asimetría es igual a 1.223725... lo cual es una asimetría positiva, esto .significando que existen más valores más altos que la media que valores por debajo de la media.

# %%
from scipy.stats import skew, ttest_ind, chi2_contingency
skew_weight = skew(response_df['Weight'].dropna())
print(f"Asimetría de la variable Weight: {skew_weight}")
if skew_weight > 0:
    print("La distribución de Weight es asimétrica positiva.")
elif skew_weight < 0:
    print("La distribución de Weight es asimétrica negativa.")
else:
    print("La distribución de Weight es simétrica.")
# Out:
# Asimetría de la variable Weight: 1.2218702827632462
# La distribución de Weight es asimétrica positiva.

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
missing_weight = response_df['Weight'].isnull().sum()
print(f"Número de valores faltantes en 'Weight': {missing_weight}")

missing_weight_percent = (missing_weight / len(response_df)) * 100
print(f"Porcentaje de valores faltantes en 'Weight': {missing_weight_percent:.2f}%")
# Out:
# Número de valores faltantes en 'Weight': 20
# Porcentaje de valores faltantes en 'Weight': 1.98%

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas. NO olvides incluir las conclusiones del análisis con los resultados obtenidos.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
# !pip install nbformat
import nbformat

notebook_path = '/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento/Missing_Values.ipynb'
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind, chi2_contingency

response_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento/responses.csv")


group_with_nan = response_df[response_df['Weight'].isnull()]
group_without_nan = response_df[response_df['Weight'].notnull()]

print("Análisis de la variable 'Age':")
Diagnose_MV_Numerical(response_df, 'Age', response_df['Weight'].isnull())

print("\nAnálisis de la variable 'Number of siblings':")
Diagnose_MV_Numerical(response_df, 'Number of siblings', response_df['Weight'].isnull())

print("\nAnálisis de la variable 'Gender':")
Diagnose_MV_Categorical(response_df, 'Gender', response_df['Weight'].isnull())

print("\nAnálisis de la variable 'Education':")
Diagnose_MV_Categorical(response_df, 'Education', response_df['Weight'].isnull())
# Out:
# ...
# Análisis de la variable 'Age':
# p-value of t-test: 0.7258243979822129
#
# Análisis de la variable 'Number of siblings':
# p-value of t-test: 0.8255092107556896
#
# Análisis de la variable 'Gender':
# p-value of Chi_squared test: 0.5472167199163878
#
# Análisis de la variable 'Education':
# p-value of Chi_squared test: 0.8424822989541867

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %%
response_df['Weight'].fillna(response_df['Weight'].median(), inplace=True)
response_df['Weight']
# Out:
# <ipython-input-86-9482d64bfa75>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   response_df['Weight'].fillna(response_df['Weight'].median(), inplace=True)
# 0       48.0
# 1       58.0
# 2       67.0
# 3       59.0
# 4       59.0
#         ...
# 1005    57.0
# 1006    80.0
# 1007    75.0
# 1008    58.0
# 1009    72.0
# Name: Weight, Length: 1010, dtype: float64

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
plt.boxplot(response_df['Weight'].dropna())
plt.title("Boxplot de Weight")
plt.show()

Q1 = response_df['Weight'].quantile(0.25)
Q3 = response_df['Weight'].quantile(0.75)
IQR = Q3 - Q1
outliers_weight = response_df[(response_df['Weight'] < (Q1 - 1.5 * IQR)) | (response_df['Weight'] > (Q3 + 1.5 * IQR))]
print("Valores atípicos en Weight:", len(outliers_weight))

response_df = response_df[~response_df.index.isin(outliers_weight.index)]
# Out:
# Valores atípicos en Weight: 10

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
plt.boxplot(response_df['Height'].dropna())
plt.title("Boxplot de Height")
plt.show()

Q1_height = response_df['Height'].quantile(0.25)
Q3_height = response_df['Height'].quantile(0.75)
IQR_height = Q3_height - Q1_height
outliers_height = response_df[(response_df['Height'] < (Q1_height - 1.5 * IQR_height)) | (response_df['Height'] > (Q3_height + 1.5 * IQR_height))]
print("Valores atípicos en Height:", len(outliers_height))

response_df = response_df[~response_df.index.isin(outliers_height.index)]
# Out:
# Valores atípicos en Height: 5

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
response_df['Height_m'] = response_df['Height'] / 100  # Convertir cm a metros
response_df['BMI'] = response_df['Weight'] / (response_df['Height_m'] ** 2)

plt.boxplot(response_df['BMI'].dropna())
plt.title("Boxplot de BMI")
plt.show()
# Out:
# <ipython-input-89-abfe3d34c1e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   response_df['Height_m'] = response_df['Height'] / 100  # Convertir cm a metros
# <ipython-input-89-abfe3d34c1e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   response_df['BMI'] = response_df['Weight'] / (response_df['Height_m'] ** 2)

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.
#
# He notado que los datos de BMI se encuentran no solo concentrados sino también altos con la variable doctorate degree y por lo general eso conlleva una edad mayor a 25 años, haciendo que la variable Age también juegue un rol importante en la dispersión de datos generales de BMI

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for column in ['Gender', 'Education']:
    plt.figure(figsize=(18, 6))
    sns.boxplot(x=column, y='BMI', data=response_df)
    plt.title(f"Distribución de BMI según {column}")
    plt.grid(axis='y')
    plt.show()
